# %% [markdown]
# # <center>**REGRESIÓN LINEAL**</center>
#
# <center><img src="https://www.statdeveloper.com/wp-content/uploads/2020/01/regresion-lineal-multiple-768x428.png" alt="drawing" width="600" /></center>

# %% [markdown]
# ## 1. Introducción
#
# La **[*Regresión Lineal*](https://sitiobigdata.com/2019/10/25/que-es-la-regresion-lineal/#)** es un campo de estudio que enfatiza la relación estadística entre dos variables continuas conocidas como variables de predicción y respuesta:
# * La variable predictora se denota con mayor frecuencia como $X$ y también se conoce como variable independiente.
# * La variable de respuesta se denota con mayor frecuencia como $Y$ y también se conoce como variable dependiente.
#
# En el presente documento, se hablará más en profundidad sobre el papel de la Regresión Lineal en la estadística y su aplicación en el lenguaje de programación **"Python"**.
#
# En primer lugar se hablará un poco sobre los inicios del concepto de la regresión Lineal, su implementación en la estadística y finalmente un poco de su uso en el campo de la programación o del Machine Learning acompañado de un ejemplo práctico para una mejor visualización de este algoritmo.

# %% [markdown]
# ## 2. Historia de la Regresión Lineal
#
# La primera forma de regresión lineal documentada fue el [Método de los Mínimos Cuadrados](https://es.wikipedia.org/wiki/Mínimos_cuadrados) que fue publicada por [Legendre](https://es.wikipedia.org/wiki/Adrien-Marie_Legendre) en 1805, [Gauss](https://es.wikipedia.org/wiki/Carl_Friedrich_Gauss) publicó un trabajo en donde desarrollaba de manera más profunda el método de los mínimos cuadrados, y en dónde se incluía una versión del [teorema de Gauss-Márkov](https://es.wikipedia.org/wiki/Teorema_de_Gauss-Márkov).
#
# El término regresión se utilizó por primera vez en el estudio de variables antropométricas: al comparar la estatura de padres e hijos, donde resultó que los hijos cuyos padres tenían una estatura muy superior al valor medio, tendían a igualarse a este, mientras que aquellos cuyos padres eran muy bajos tendían a reducir su diferencia respecto a la estatura media; es decir, "regresaban" al promedio. La constatación empírica de esta propiedad se vio reforzada más tarde con la justificación teórica de ese fenómeno.
#
# <div class='pull left'><center><img src="https://www.cienciadedatos.net/images/correlacion_lineal_image.jpg" alt="drawing" width="600" /></center></div>
#
# El término lineal se emplea para distinguirlo del resto de técnicas de [*regresión*](https://es.wikipedia.org/wiki/Análisis_de_la_regresión), que emplean modelos basados en cualquier clase de función matemática. Los modelos lineales son una explicación simplificada de la realidad, mucho más ágiles y con un soporte teórico mucho más extenso por parte de la matemática y la estadística. Pero bien, como se ha dicho, se puede usar el término lineal para distinguir modelos basados en cualquier clase de aplicación.
#
# Los métodos de regresión siguen siendo un área de investigación activa. En las últimas décadas, nuevos métodos han sido desarrollados para regresión robusta, regresión que implica respuestas correlacionadas, tales como series de tiempo y las curvas de crecimiento, regresión en la que los predictores (variable independiente) o las variables de respuesta son curvas, imágenes, gráficos y otros objetos de datos complejos, métodos de regresión que aceptan varios tipos de datos faltantes, regresión no paramétrica, métodos de regresión bayesianos, regresión en la que las variables predictoras son medidas con error, regresión con más variables predictoras que observaciones y la inferencia causal con regresión.

# %% [markdown]
# ## 3. Planteamiento del Algoritmo
#
# ### *- Introducción al modelo -*
#
# El modelo de la regresión lineal simple, está conformado por dos variables estadísticas llamadas $X$ y $Y$. Asumiremos que la variable $Y$ es influida por la variable $X$, de esta forma, podemos referirnos a $X$ como *Variable Independiente* o *Regresora* y a $Y$ como la *Variable Dependiente* o *Respuesta*.
#
# <center><img src="https://i.ytimg.com/vi/gfs5bp2j_bA/maxresdefault.jpg"  alt="drawing" width="600" /></center>
#
# Para la Regresión Lineal se asume que $X$ y $Y$ se relacionan mediante el modelo
#
# $$
# Y = \beta_0 + \beta_1 X + \varepsilon
# $$
#
# donde
#
# <ul type = "square">
#   <li> $Y$ es una variable estadística no determinista. </li>
#   <li> $X$ es una variable estadística determinista. </li>
#   <li> $\varepsilon$ es una variable estadística no determinista y no observable. </li>
#   <li> $\beta_0 , \beta_1 \in \mathbb{R}$ son constantes desconocidas. </li>
#   <li> $E (\varepsilon) = 0$ y $Var(\varepsilon) = \sigma^2 < \infty$. </li>
#   <li> $Cov (\varepsilon_i , \varepsilon_j) = 0$ si $i \neq j$. </li>
#   <li> $\varepsilon \sim N(0 , \sigma^2)$ (Normalidad de los errores). </li>
# </ul >
#
# Los parámetros $\beta_0$ y $\beta_1$ son conocidos como coeficientes de regresión, donde estos pueden ser estimados mediante el método de [*Mínimos cuadrados*](https://en.wikipedia.org/wiki/Least_squares) o por el método de [*Máxima Verosimilitud*](https://en.wikipedia.org/wiki/Maximum_likelihood_estimation) y $\varepsilon$ el error cometido por el modelo.
#
# Los términos $\beta_0$ y $\beta_1$ representan respectivamente el interceptor y la pendiente del modelo lineal. Son lo que se denomina coeficientes o parámetros del modelo de regresión lineal. Estos dos coeficientes son dos constantes que se obtienen por medio de lo que se denomina «entrenamiento» del modelo de regresión. Este entrenamiento se realiza con datos de los que sabemos valores reales de la tupla $(X,y)$. Una vez obtenida la estimación de estos dos coeficientes se puede predecir la variable Y usando $X$ conocidos y a partir de la siguiente fórmula:
#
# $$
# \hat{y} = \hat{\beta}_0 + \hat{\beta}_1 x \ ,
# $$
#
# siendo $\hat{y}$ la predicción que obtenemos y $\hat{\beta}_0$ y $\hat{\beta}_1$ estimaciones obtenidas con el entrenamiento.
#
# Si el término de error $\varepsilon$ es bajo para esta muestra, la predicción será aproximadamente igual al valor real:
#
# $$
# \hat{y} \approx y
# $$
#
# Por lo tanto, el entrenamiento y ajuste del modelo de regresión simple tratará de obtener los valores de $\hat{\beta}_0$ y $\hat{\beta}_1$ que mejor ajusten el modelo, es decir, mejor predigan el $Y$ en función de $X$.
#
# <center><img src="https://www.iartificial.net/wp-content/uploads/2018/12/ejemplo-error-cuadratico-medio2.webp"></center>
#
# ### *- Estimación de los Coeficientes -*
#
# Como se mencióno anteriormente, la estimación de los coeficientes se realiza con valores reales conocidos de la tupla $(X,y)$. Suponga que se tienen $n$ registros con variable independiente y dependiente conocidas:
#
# $$
# (x_1 , y_1), (x_2, y_2), ... , (x_n , y_n)
# $$
#
# Con estas n observaciones, el objetivo es obtener las estimaciones de los coeficientes $\hat{\beta}_0$ y $\hat{\beta}_1$ que hagan que el modelo lineal se ajuste lo mejor posible a los datos. Es decir, que $\hat{y}_i = \hat{\beta}_0 + \hat{\beta}_1 x_i$ para todos los $x_i$, o lo que es lo mismo, encontrar la pendiente y la ordenada en el origen de la recta que pasa más cerca de los puntos $(x_i,y_i)$.
#
# Esta medida de cercania entre la recta y los puntos se puede hacer de distintas formas, siendo la forma más común la de ajustar por mínimos cuadrados (less squares criterion).
#
# #### **Estimación por mínimos cuadrados**
#
# Siendo $\hat{y}_i = \hat{\beta}_0 + \hat{\beta}_1 x_i$ las predicciones de $y_i$, el residuo o diferencia entre la preddición y el valor real es:
#
# $$
# r_i = y_i - \hat{y}_i
# $$
#
# El método de mínimos cuadrados obtendrá los coeficientes que minimicen la suma de residuos al cuadrado, es decir, que minimicen:
#
# $$
# RSS = \sum_{i=1}^n r_i^2 \ .
# $$
#
# Usando derivadas parciales e igualando a $0$ obtenemos que:
#
# $$
# \left\{ \begin{array}{cc}
#         \frac{\partial RSS}{\partial \hat{\beta}_1} = 0 \longrightarrow \hat{\beta}_1 = \frac{\sum_{i=1}^n (x_i - \overline{x})(y_i - \overline{x})}{\sum_{i=1}^n (x_i - \overline{x})^2} \\
#         \frac{\partial RSS}{\partial \hat{\beta}_0} = 0 \longrightarrow \hat{\beta}_0 = \overline{y} - \hat{\beta}_1 \overline{x}
#         \end{array} \right.
# $$
#
# Siendo $\overline{x}$ y $\overline{y}$ las medias aritméticas de las muestras.
#
# En la siguiente sección, veremos de mejor manera su implementación en *Python* por medio de un ejemplo práctico.

# %% [markdown]
# ## 4. Ejemplo Práctico
#
# Ahora, luego de tocar el tema de la Regresión Lineal y un breve recorrido por su historia, veámos su aplicación en el campo de la programación o también conocido como Machine Learning. Para ello, haremos uso del software "*Python*".
#
# <center><img src="https://miro.medium.com/max/700/1*TzBsVJUXqofGqdsBJRvXEw.png" alt="drawing" width="600" /></center>
#
# Dado un conjunto de puntos, el algoritmo de regresión establecerá un modelo para ajustar la relación de dependencia entre una característica específica independiente (un valor de la variable independiente $X$) y el valor “resultado” correspondiente (un valor de la variable dependiente $Y$). Esta relación se realiza estableciendo una línea arbitraria y calculando la distancia de la recta a los puntos de datos correspondientes a los valores $(x,y)$. Esta distancia, las líneas verticales, son los “residuos” o los “errores de predicción”.
#
# Para poder implementar el algortimo de la Regresión Lineal, se mide el error con respecto a los puntos de entrada y el valor “Y” de salida real. La función del algoritmo será la de minimizar el coste de una función de error cuadrático y esos coeficientes corresponderán con la recta óptima.
#
# En otras palabras, el algoritmo de regresión recalculará (y moverá) la recta con cada interacción, buscando aquella que mejor se ajuste a los puntos de datos $(x,y)$, o lo que sería, la línea con el menor error (la más cercana al máximo número de puntos).
#
# A continuación comenzaremos con el proceso de implementación del algoritmo aplicado a un ejemplo práctico. Para realizar este ejercicio, haremos uso de la librería ***SkLearn*** muy utilizada en Data Science.
#
# ### ***- Descripción del Problema -***
#
# Para la realización de este ejercicio práctico, se hará uso de una base de datos tomada de la plataforma **Kaggle** mediante el siguiente [*link*](https://www.kaggle.com/quantbruce/real-estate-price-prediction), en la cual se quiere realizar una predicción de los precios inmobiliarios para una ciudad desconocida. En este problema, se hace uso de la Regresión Lineal Múltiple, es decir que se tomarán en cuenta un total de 3 variables regresoras y una única variable respuesta.
#
# Esta base de datos está compuesta por un total de 8 variables, las cuales son:
#
# - "$X_1$": Fecha de transacción.
#
# - "$X_2$": Antigüedad de la vivienda.
#
# - "$X_3$": Distancia a la estación de metro más cercana.
#
# - "$X_4$": Número de tiendas de conveniencia cerca.
#
# - "$X_5$": Latitud (Ubicación).
#
# - "$X_6$": Longitud (Ubicación).
#
# - "$Y$": Precio de la vivienda de la unidad de área.
#
# Finalmente, para mayor practicidad del ejercicio, haremos uso únicamente de las variables $X_2$, $X_3$, $X_4$ y $Y$.

# %% [markdown]
# ### ***- Librerias necesarias -***

# %% [markdown]
# Las librerias necesarias para la realización de este ejercicio práctico, son las siguientes:

# %%
# Importes de librerias necesarias para la realización del ejemplo #

# ---------- Tratamiento de datos ---------- #
import numpy as np
import pandas as pd

# ---------- Trazado de Gráficos ---------- #
import matplotlib.pyplot as plt
from matplotlib import style
from matplotlib import cm
import seaborn as sns

# ---------- Procesado y Modelado ---------- #
from scipy.stats import pearsonr
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.stats.anova import anova_lm
from scipy import stats

# ---------- Configuración de Matplotlib ---------- #
plt.rcParams['image.cmap'] = "bwr"
plt.rcParams['savefig.bbox'] = "tight"
# plt.rcParams['figure.figsize'] = (16, 9)
style.use('ggplot') or plt.style.use('ggplot')

# ---------- Configuración de Warnings ---------- #
import warnings
warnings.filterwarnings('ignore')
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ### ***- Conjunto de Datos Utilizados -***

# %% [markdown]
# A continuación se hace uso de una base de datos la cual se encuentra en un archivo .csv y para ello, se utiliza la librería *Pandas*.

# %%
# ---------- Configuración de Google Drive ---------- #
from google.colab import drive
drive.mount('/content/drive')

# ---------- Ruta del Archivo a escoger ---------- #
ruta = '/content/drive/MyDrive/Colab Notebooks/Bases de Datos - Tarea No. 2/Real estate.csv'

# ---------- Cargamos los Datos de entrada usando Pandas ---------- #
data = pd.read_csv(ruta)

# ---------- Vemos las dimensiones y registros que tiene ---------- #
data.shape
# Out:
# Mounted at /content/drive
# (414, 8)

# %% [markdown]
# Por lo que podemos ver que el conjunto de datos utilizado está conformado por un total de 414 registros distribuidos en un total de 8 columnas.

# %%
# ---------- Vemos las variables presentes ---------- #
data.columns
# Out:
# Index(['No', 'X1 transaction date', 'X2 house age',
#        'X3 distance to the nearest MRT station',
#        'X4 number of convenience stores', 'X5 latitude', 'X6 longitude',
#        'Y house price of unit area'],
#       dtype='object')

# %% [markdown]
# Para mayor facilidad a la hora de hacer uso del conjunto de ddatos, generaremos nuevos nombres a las variables según lo escrito anteriormente en la descripción al problema

# %%
# ---------- Cambiamos los nombres de las variables ---------- #
data.columns = ['No.','X1','X2','X3','X4','X5','X6','Y']
data.columns
# Out:
# Index(['No.', 'X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'Y'], dtype='object')

# %% [markdown]
# Vemos algunos de los primeros registros que tiene la base de datos.

# %%
# ---------- Observamos unos de los registros que tienen los datos ---------- #
data.head()
# Out:
#    No.        X1    X2         X3  X4        X5         X6     Y
# 0    1  2012.917  32.0   84.87882  10  24.98298  121.54024  37.9
# 1    2  2012.917  19.5  306.59470   9  24.98034  121.53951  42.2
# 2    3  2013.583  13.3  561.98450   5  24.98746  121.54391  47.3
# 3    4  2013.500  13.3  561.98450   5  24.98746  121.54391  54.8
# 4    5  2012.833   5.0  390.56840   5  24.97937  121.54245  43.1

# %% [markdown]
# Observamos el tipo de variable que tiene cada una de las columnas que componen los datos.

# %%
# ---------- Tipos de Variables que componen los datos ---------- #
data.dtypes
# Out:
# No.      int64
# X1     float64
# X2     float64
# X3     float64
# X4       int64
# X5     float64
# X6     float64
# Y      float64
# dtype: object

# %% [markdown]
# Como se hace uso únicamente de las variables $X_2$, $X_3$, $X_4$ y $Y$, haremos un cambio de variables para las cuales no haremos uso, por lo que las volveremos de tipo "*string*" para que no interfieran en la resolución de este ejercicio.

# %%
# ---------- Cambio de tipo de Variable para algunos registros ---------- #
data['No.'] = data['No.'].astype(str)
data['X1'] = data['X1'].astype(str)
data['X5'] = data['X5'].astype(str)
data['X6'] = data['X6'].astype(str)

# %% [markdown]
# Observamos nuevamente los tipos de variables para verificar que se realizó el cambio realizado anteriormente.

# %%
# ---------- Tipos de Variables que componen los datos ---------- #
data.dtypes
# Out:
# No.     object
# X1      object
# X2     float64
# X3     float64
# X4       int64
# X5      object
# X6      object
# Y      float64
# dtype: object

# %% [markdown]
# Ahora, generamos una matriz de correlación generada en "*Pandas*" y la transformamos en formato tidy mediante la siguiente función.

# %%
# ---------- Matriz de Correlación en Formato Tidy ---------- #

def tidy_corr_matrix(corr_mat):
    '''
    Función para convertir una matriz de correlación de pandas en formato tidy
    '''
    corr_mat = corr_mat.stack().reset_index()
    corr_mat.columns = ['variable_1','variable_2','r']
    corr_mat = corr_mat.loc[corr_mat['variable_1'] != corr_mat['variable_2'], :]
    corr_mat['abs_r'] = np.abs(corr_mat['r'])
    corr_mat = corr_mat.sort_values('abs_r', ascending=False)
    
    return(corr_mat)

corr_matrix = data.select_dtypes(include=['float64', 'int']).corr(method='pearson')
tidy_corr_matrix(corr_matrix).head(10)
# Out:
#    variable_1 variable_2         r     abs_r
# 7          X3          Y -0.673613  0.673613
# 13          Y         X3 -0.673613  0.673613
# 6          X3         X4 -0.602519  0.602519
# 9          X4         X3 -0.602519  0.602519
# 11         X4          Y  0.571005  0.571005
# 14          Y         X4  0.571005  0.571005
# 3          X2          Y -0.210567  0.210567
# 12          Y         X2 -0.210567  0.210567
# 2          X2         X4  0.049593  0.049593
# 8          X4         X2  0.049593  0.049593

# %% [markdown]
# Luego, realizamos una matriz de correlaciones mediante un *Heatmap* en donde se encuentran las variables consideradas para el estudio de este ejemplo.

# %%
# ---------- Heatmap / Matriz de Correlaciones ---------- #

df = pd.DataFrame(data)

# taking all rows but only 6 columns
df_small = df.iloc[:,:]

correlation_mat = df_small.corr()

sns.heatmap(correlation_mat, annot = True)

plt.show()

# %% [markdown]
# Se realiza un gráfico de distribuciones para las variables numéricas utilizadas, es decir, únicamente las variables consideradas al inicio de este ejercicio.

# %%
# ---------- Gráfico de distribución para cada variable numérica ---------- #

# Ajustar número de subplots en función del número de columnas
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(9, 5))
axes = axes.flat
columnas_numeric = data.select_dtypes(include=['float64', 'int']).columns

for i, colum in enumerate(columnas_numeric):
    sns.histplot(
        data    = data,
        x       = colum,
        stat    = "count",
        kde     = True,
        color   = (list(plt.rcParams['axes.prop_cycle'])*2)[i]["color"],
        line_kws= {'linewidth': 2},
        alpha   = 0.3,
        ax      = axes[i]
    )
    axes[i].set_title(colum, fontsize = 10, fontweight = "bold")
    axes[i].tick_params(labelsize = 8)
    axes[i].set_xlabel("")

fig.tight_layout()
plt.subplots_adjust(top = 0.9)
fig.suptitle('Distribución variables numéricas', fontsize = 10, fontweight = "bold");

# %% [markdown]
# Luego, proseguimos con el ajuste del Modelo

# %% [markdown]
# ### ***- Ajuste del Modelo -***

# %% [markdown]
# Se ajusta un modelo lineal múltiple con el objetivo de predecir las ventas en función de la inversión en los tres canales de publicidad.  El modelo pensado a ajustar sería
# $$
# Y = \beta_0 + \beta_1 X_2 + \beta_2 X_3 + \beta_3 X_4 + \varepsilon
# $$

# %%
# ---------- División de los datos en train y test ---------- #
X = data[['X2', 'X3', 'X4']]
y = data['Y']

X_train, X_test, y_train, y_test = train_test_split(
                                        X,
                                        y.values.reshape(-1,1),
                                        train_size   = 0.8,
                                        random_state = 1234,
                                        shuffle      = True
                                    )

# %%
# ---------- Creación del modelo utilizando matrices como en scikitlearn ---------- #
# A la matriz de predictores se le tiene que añadir una columna de 1s para el intercept del modelo
X_train = sm.add_constant(X_train, prepend=True)
modelo = sm.OLS(endog=y_train, exog=X_train,)
modelo = modelo.fit()
print(modelo.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.580
# Model:                            OLS   Adj. R-squared:                  0.576
# Method:                 Least Squares   F-statistic:                     150.5
# Date:                Thu, 11 Mar 2021   Prob (F-statistic):           2.77e-61
# Time:                        21:26:35   Log-Likelihood:                -1182.9
# No. Observations:                 331   AIC:                             2374.
# Df Residuals:                     327   BIC:                             2389.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         41.6149      1.474     28.233      0.000      38.715      44.515
# ...

# %% [markdown]
# Por lo tanto, a partir del summary generado anteriormente, tenemos que nuestro modelo ajustado está dado por la ecuación
#
# $$
# Y = 41.6149 - 0.2017 X_2 - 0.0054 X_3 + 1.3750 X_4
# $$

# %% [markdown]
# ### ***- Intervalos de Confianza para el Modelo -***

# %% [markdown]
# Para una mayor practicidad y mejor profundización en el tema, generaremos unos intervalos de confianza correspondientes a las variables del modelo.

# %%
# ---------- Intervalos de confianza para los coeficientes del modelo ---------- #
intervalos_ci = modelo.conf_int(alpha=0.05)
intervalos_ci.columns = ['2.5%', '97.5%']
intervalos_ci
# Out:
#             2.5%      97.5%
# const  38.715221  44.514670
# X2     -0.285122  -0.118197
# X3     -0.006314  -0.004452
# X4      0.966724   1.783331

# %% [markdown]
# ### ***- Diagnóstico para los residuos -***

# %%
# ---------- Diagnóstico errores (residuos) de las predicciones de entrenamiento ---------- #
y_train = y_train.flatten()
prediccion_train = modelo.predict(exog = X_train)
residuos_train = prediccion_train - y_train

# %% [markdown]
# #### Inspección visual

# %%
# ---------- Gráficos ---------- #
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(9, 8))

axes[0, 0].scatter(y_train, prediccion_train, edgecolors=(0, 0, 0), alpha = 0.4)
axes[0, 0].plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()],
                'k--', color = 'black', lw=2)
axes[0, 0].set_title('Valor predicho vs valor real', fontsize = 10, fontweight = "bold")
axes[0, 0].set_xlabel('Real')
axes[0, 0].set_ylabel('Predicción')
axes[0, 0].tick_params(labelsize = 7)

axes[0, 1].scatter(list(range(len(y_train))), residuos_train,
                   edgecolors=(0, 0, 0), alpha = 0.4)
axes[0, 1].axhline(y = 0, linestyle = '--', color = 'black', lw=2)
axes[0, 1].set_title('Residuos del modelo', fontsize = 10, fontweight = "bold")
axes[0, 1].set_xlabel('id')
axes[0, 1].set_ylabel('Residuo')
axes[0, 1].tick_params(labelsize = 7)

sns.histplot(
    data    = residuos_train,
    stat    = "density",
    kde     = True,
    line_kws= {'linewidth': 1},
    color   = "firebrick",
    alpha   = 0.3,
    ax      = axes[1, 0]
)

axes[1, 0].set_title('Distribución residuos del modelo', fontsize = 10,
                     fontweight = "bold")
axes[1, 0].set_xlabel("Residuo")
axes[1, 0].tick_params(labelsize = 7)


sm.qqplot(
    residuos_train,
    fit   = True,
    line  = 'q',
    ax    = axes[1, 1], 
    color = 'firebrick',
    alpha = 0.4,
    lw    = 2
)
axes[1, 1].set_title('Q-Q residuos del modelo', fontsize = 10, fontweight = "bold")
axes[1, 1].tick_params(labelsize = 7)

axes[2, 0].scatter(prediccion_train, residuos_train,
                   edgecolors=(0, 0, 0), alpha = 0.4)
axes[2, 0].axhline(y = 0, linestyle = '--', color = 'black', lw=2)
axes[2, 0].set_title('Residuos del modelo vs predicción', fontsize = 10, fontweight = "bold")
axes[2, 0].set_xlabel('Predicción')
axes[2, 0].set_ylabel('Residuo')
axes[2, 0].tick_params(labelsize = 7)

# Se eliminan los axes vacíos
fig.delaxes(axes[2,1])

fig.tight_layout()
plt.subplots_adjust(top=0.9)
fig.suptitle('Diagnóstico residuos', fontsize = 12, fontweight = "bold");

# %% [markdown]
# #### Test de Normalidad

# %%
# ---------- Normalidad de los residuos Shapiro-Wilk test ---------- #
shapiro_test = stats.shapiro(residuos_train)
shapiro_test
# Out:
# (0.9440319538116455, 7.181163996783368e-10)

# %%
# ---------- Configuración de Warnings ---------- #
# Normalidad de los residuos D'Agostino's K-squared test
# ==============================================================================
k2, p_value = stats.normaltest(residuos_train)
print(f"Estadítico= {k2}, p-value = {p_value}")
# Out:
# Estadítico= 48.00504928396377, p-value = 3.7656157020116975e-11

# %% [markdown]
# #### Predicciones

# %%
# ---------- Predicciones con intervalo de confianza  ---------- #
predicciones = modelo.get_prediction(exog = X_train).summary_frame(alpha=0.05)
predicciones.head(4)
# Out:
#           mean   mean_se  ...  obs_ci_lower  obs_ci_upper
# 97   36.689164  0.813600  ...     19.539070     53.839258
# 168  40.151398  0.677651  ...     23.024194     57.278603
# 348  47.539707  0.811078  ...     30.390075     64.689338
# 167  45.151500  0.884466  ...     27.987834     62.315166
#
# [4 rows x 6 columns]

# %% [markdown]
# ### ***- Error del Test -***

# %%
# ---------- Error de test del modelo  ---------- #
X_test = sm.add_constant(X_test, prepend=True)
predicciones = modelo.predict(exog = X_test)
rmse = mean_squared_error(
        y_true  = y_test,
        y_pred  = predicciones,
        squared = False
       )
print("")
print(f"El error (rmse) de test es: {rmse}")
# Out:
# El error (rmse) de test es: 11.31778367928381

# %% [markdown]
# ## 5. Conclusiones
#
# ![Imagen Conclusiones.jpg](data:image/jpeg;base64,...)
#
# Durante el desarrollo de este trabajo, se observo en brevedad parte de la historia que conforma la Regresión Lineal. Del mismo modo, vimos como se puede aplicar al desarrollo del Machine Learning, mediante el uso de SKLearn en Python para la creación de modelos de Regresión Lineal con múltiples variables (del mismo modo, se pueden generar modelos para una única variable).
#
# En el ejercicio planteado, el único propósito fue el de dar un vistazo general al desarrollo de un modelo de regresión lineal aplicado a un conjunto de datos, por lo que no es posible realizar una predicción a este modelo. Si se desea realizar una investigación más profunda, es posible continuar con la base aquí planteada para continuar con su desarrollo.

# %% [markdown]
# ## 6. Bibliografía
#
# 1. Información de ayuda para manejo en Python:
#
#   - https://www.analyticslane.com/2019/05/06/como-cambiar-el-nombre-de-las-columnas-en-pandas/
#
#   - https://www.delftstack.com/es/howto/python-pandas/how-to-convert-pandas-dataframe-column-to-string/
#
#   - https://support.zendesk.com/hc/es/articles/203691016-Uso-de-Markdown-para-el-formato-de-texto#topic_xqx_mvc_43__row_lkm_tln_1n
#
#   - https://fobos.inf.um.es/R/taller5j/30-markdown/guiabreve.pdf
#
#   - https://www.master-data-scientist.com/scikit-learn-data-science/
#
# 2. Información sobre la regresión Lineal:
#
#   - Regresión lineal con Python by Joaquín Amat Rodrigo, available under a Attribution 4.0 International (CC BY 4.0). [Link](https://www.cienciadedatos.net/documentos/py10-regresion-lineal-python.html)
#
#   - https://medium.com/datos-y-ciencia/machine-learning-supervisado-fundamentos-de-la-regresión-lineal-bbcb07fe7fd
#
#   - https://www.aprendemachinelearning.com/regresion-lineal-en-espanol-con-python/
#
#   - https://sitiobigdata.com/2019/10/25/que-es-la-regresion-lineal/#
#
#   - https://machinelearningparatodos.com/regresion-lineal-en-python/
#
#   - https://www.iartificial.net/regresion-lineal-con-ejemplos-en-python/
#
#   - https://www.jacobsoft.com.mx/es_mx/regresion-lineal-simple-con-python/
#
# 3. Base de datos utilizada. [Link](https://www.kaggle.com/quantbruce/real-estate-price-prediction)
